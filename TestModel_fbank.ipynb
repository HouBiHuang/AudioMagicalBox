# %%
import sounddevice as sd
import numpy as np
import scipy.signal
import python_speech_features
import tensorflow as tf
from PyQt5.QtCore import QTime
import librosa
from tensorflow.keras import layers, models

# %%
#錄音檔測試TestWAV1
TN = 0
TP = 0
FP = 0
FN = 0

# This gets called every 0.5 seconds
def sound(window,s,m):
    global TN
    global TP
    global FP
    global FN
    S = np.abs(librosa.stft(window)) #將整個window音訊做stft，並轉成絕對值
    
    if np.sum(S) >= 500: #判斷S的總和是否>=500，如果>=500，代表有明顯的聲音
        window = window.astype(np.float)

        window = (window - window.mean()) / (window.max() - window.min())

        features = python_speech_features.base.logfbank(window,
                                                        samplerate=16000,
                                                        winlen=0.025,
                                                        winstep=0.01,
                                                        nfilt=26,
                                                        nfft=512,
                                                        lowfreq=0,
                                                        highfreq=None,
                                                        preemph=0.97)

        features = np.float32(features.reshape(1, features.shape[0], features.shape[1], 1))

        prediction = model.predict(features).reshape((15, ))
        prediction /= prediction.sum()
        best_candidate_index = prediction.argmax()

        best_candidate_probability = prediction[best_candidate_index]
        
        if(best_candidate_probability > 0.9):
            if((s == 5 and str(all_targets[best_candidate_index]) == '吼') or (s == 5.25 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 5) or (s == 5.25)):
                FN = FN + 1
            elif((s == 9.5 and str(all_targets[best_candidate_index]) == 'ㄏㄧㄡ') or (s == 9.75 and str(all_targets[best_candidate_index]) == 'ㄏㄧㄡ')):
                TP = TP + 1
            elif((s == 9.5) or (s == 9.75)):
                FN = FN + 1
            elif((s == 10.25 and str(all_targets[best_candidate_index]) == '那') or (s == 10.5 and str(all_targets[best_candidate_index]) == '那')):
                TP = TP + 1
            elif((s == 10.25) or (s == 10.5)):
                FN = FN + 1
            elif((s == 17.25 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 17.25)):
                FN = FN + 1
            elif((s == 17.75 and str(all_targets[best_candidate_index]) == '啦') or (s == 18 and str(all_targets[best_candidate_index]) == '啦')):
                TP = TP + 1
            elif((s == 17.75) or (s == 18)):
                FN = FN + 1
            elif((s == 23 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 23)):
                FN = FN + 1
            elif((s == 23.5 and str(all_targets[best_candidate_index]) == 'ㄟ') or (s == 23.75 and str(all_targets[best_candidate_index]) == 'ㄟ')):
                TP = TP + 1
            elif((s == 23.5) or (s == 23.75)):
                FN = FN + 1
            elif((s == 34.25 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 34.25)):
                FN = FN + 1
            elif((s == 34.75 and str(all_targets[best_candidate_index]) == '嗯') or (s == 35 and str(all_targets[best_candidate_index]) == '嗯') or (s == 35.25 and str(all_targets[best_candidate_index]) == '嗯')):
                TP = TP + 1
            elif((s == 34.75) or (s == 35) or (s == 35.25)):
                FN = FN + 1
            elif((s == 42.5 and str(all_targets[best_candidate_index]) == '啦') or (s == 42.75 and str(all_targets[best_candidate_index]) == '啦')):
                TP = TP + 1
            elif((s == 42.5) or (s == 42.75)):
                FN = FN + 1
            elif((s == 43.25 and str(all_targets[best_candidate_index]) == 'ㄏㄧㄡ') or (s == 43.5 and str(all_targets[best_candidate_index]) == 'ㄏㄧㄡ')):
                TP = TP + 1
            elif((s == 43.25) or (s == 43.5)):
                FN = FN + 1
            elif((s == 49.25 and str(all_targets[best_candidate_index]) == 'ㄟ') or (s == 49.5 and str(all_targets[best_candidate_index]) == 'ㄟ') or (s == 49.75 and str(all_targets[best_candidate_index]) == 'ㄟ')):
                TP = TP + 1
            elif((s == 49.25) or (s == 49.5) or (s == 49.75)):
                FN = FN + 1
            elif((s == 54.5 and str(all_targets[best_candidate_index]) == '嗯') or (s == 54.75 and str(all_targets[best_candidate_index]) == '嗯')):
                TP = TP + 1
            elif((s == 54.5) or (s == 54.75)):
                FN = FN + 1
            elif((s == 58 and str(all_targets[best_candidate_index]) == '阿') or (s == 58.25 and str(all_targets[best_candidate_index]) == '阿')):
                TP = TP + 1
            elif((s == 58) or (s == 58.25)):
                FN = FN + 1
            elif((s == 59.25 and str(all_targets[best_candidate_index]) == '阿')):
                TP = TP + 1
            elif((s == 59.25)):
                FN = FN + 1
            elif(str(all_targets[best_candidate_index]) != '其它' and str(all_targets[best_candidate_index]) != '他' and str(all_targets[best_candidate_index]) != '你' and str(all_targets[best_candidate_index]) != '我' and str(all_targets[best_candidate_index]) != '的' and str(all_targets[best_candidate_index]) != '好' and str(all_targets[best_candidate_index]) != 'backgroundNoise'):
                FP = FP + 1
            else:
                TN = TN + 1
        else:
            if(s != 5 and s != 5.25 and s != 9.5 and s != 9.75 and s != 10.25 and s != 10.5 and s != 17.25 and s != 17.75 and s != 18 and s != 23 and s != 23.5 and s != 23.75 and s != 30.25 and s != 34.25 and s != 34.75 and s != 35 and s != 35.25 and s != 42.5 and s != 42.75 and s != 43.25 and s != 43.5 and s != 49.25 and s != 49.5 and s != 49.75 and s != 54.5 and s != 54.75 and s != 58 and s != 58.25 and s != 59.25):
                TN = TN + 1
            else:
                FN = FN + 1

#main
# Parameters
model_path = './h5_normalize/recording9_fbank.h5'
all_targets = ['backgroundNoise', 'ㄏㄧㄡ', 'ㄟ', '他', '你', '其他', '吼', '啦', '嗯', '好', '我', '的', '著', '那', '阿']

start = 0 #一開始的索引值
end = 4000 #一開始的索引值
s = 0 #秒
m = 0 #分
duration = 60 #讀音檔的總時間
sample_rate = 16000 #取樣率

#載入音檔
y, sr = librosa.load("./TestWAV/TestWAV1.wav",sr=sample_rate,duration=duration) 

# Sliding window
window = np.zeros(8000)#取樣音頻數據變數

# Load model
model = models.load_model(model_path)


while True:
    s = s + 0.25 #增加秒數
    if(s >= 60): #60秒 轉成 1分
        s = 0
        m = m + 1

    window[:4000] = window[4000:] #把音訊載入window
    window[4000:] = y[start:end] #把音訊載入window
    
    sound(window,s,m) #呼叫sound()

    if(end == (16000 * duration)): #如果移動到最後，break
        break
    
    start = start + 4000 #向後移動
    end = end + 4000 #向後移動    
    
print("TP = " + str(TP))
print("TN = " + str(TN))
print("FP = " + str(FP))
print("FN = " + str(FN))

# %%
#錄音檔測試TestWAV2
TN = 0
TP = 0
FP = 0
FN = 0

# This gets called every 0.5 seconds
def sound(window,s,m):
    global TN
    global TP
    global FP
    global FN
    S = np.abs(librosa.stft(window)) #將整個window音訊做stft，並轉成絕對值
    
    if np.sum(S) >= 500: #判斷S的總和是否>=500，如果>=500，代表有明顯的聲音
        window = window.astype(np.float)

        window = (window - window.mean()) / (window.max() - window.min())

        features = python_speech_features.base.logfbank(window,
                                                        samplerate=16000,
                                                        winlen=0.025,
                                                        winstep=0.01,
                                                        nfilt=26,
                                                        nfft=512,
                                                        lowfreq=0,
                                                        highfreq=None,
                                                        preemph=0.97)

        features = np.float32(features.reshape(1, features.shape[0], features.shape[1], 1))

        prediction = model.predict(features).reshape((15, ))
        prediction /= prediction.sum()
        best_candidate_index = prediction.argmax()

        best_candidate_probability = prediction[best_candidate_index]
        
        if(best_candidate_probability > 0.9):
            if((s == 3.25 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 3.25)):
                FN = FN + 1
            elif((s == 5 and str(all_targets[best_candidate_index]) == '吼') or (s == 5.25 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 5) or (s == 5.25)):
                FN = FN + 1
            elif((s == 5.75 and str(all_targets[best_candidate_index]) == '那') or (s == 6 and str(all_targets[best_candidate_index]) == '那')):
                TP = TP + 1
            elif((s == 5.75) or (s == 6)):
                FN = FN + 1
            elif((s == 8.75 and str(all_targets[best_candidate_index]) == '吼') or (s == 9 and str(all_targets[best_candidate_index]) == '吼')  or (s == 9 and str(all_targets[best_candidate_index]) == '那')):
                TP = TP + 1
            elif((s == 8.75) or (s == 9)):
                FN = FN + 1
            elif((s == 9.25 and str(all_targets[best_candidate_index]) == '那')):
                TP = TP + 1
            elif((s == 9.25)):
                FN = FN + 1
            elif((s == 11.25 and str(all_targets[best_candidate_index]) == '那') or (s == 11.5 and str(all_targets[best_candidate_index]) == '那')):
                TP = TP + 1
            elif((s == 11.25) or (s == 11.5)):
                FN = FN + 1
            elif((s == 11.75 and str(all_targets[best_candidate_index]) == '吼') or (s == 12 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 11.75) or (s == 12)):
                FN = FN + 1
            elif((s == 13 and str(all_targets[best_candidate_index]) == '吼') or (s == 13.25 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 13) or (s == 13.25)):
                FN = FN + 1
            elif((s == 14 and str(all_targets[best_candidate_index]) == '吼') or (s == 14.25 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 14) or (s == 14.25)):
                FN = FN + 1
            elif((s == 14.75 and str(all_targets[best_candidate_index]) == '那') or (s == 15 and str(all_targets[best_candidate_index]) == '那') or (s == 15.25 and str(all_targets[best_candidate_index]) == '那')):
                TP = TP + 1
            elif((s == 14.75) or (s == 15) or (s == 15.25)):
                FN = FN + 1
            elif((s == 16.25 and str(all_targets[best_candidate_index]) == '吼') or (s == 16.5 and str(all_targets[best_candidate_index]) == '吼') or (s == 16.5 and str(all_targets[best_candidate_index]) == '那')):
                TP = TP + 1
            elif((s == 16.25) or (s == 16.5)):
                FN = FN + 1
            elif((s == 16.75 and str(all_targets[best_candidate_index]) == '那')):
                TP = TP + 1
            elif((s == 16.75)):
                FN = FN + 1
            elif((s == 19.25 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 19.25)):
                FN = FN + 1
            elif((s == 23.5 and str(all_targets[best_candidate_index]) == '那') or (s == 23.75 and str(all_targets[best_candidate_index]) == '那')):
                TP = TP + 1
            elif((s == 23.5) or (s == 23.75)):
                FN = FN + 1
            elif((s == 28 and str(all_targets[best_candidate_index]) == '吼') or (s == 28.25 and str(all_targets[best_candidate_index]) == '吼') or (s == 28.25 and str(all_targets[best_candidate_index]) == '那')):
                TP = TP + 1
            elif((s == 28) or (s == 28.25)):
                FN = FN + 1
            elif((s == 28.5 and str(all_targets[best_candidate_index]) == '那')):
                TP = TP + 1
            elif((s == 28.5)):
                FN = FN + 1
            elif((s == 31.5 and str(all_targets[best_candidate_index]) == '吼') or (s == 31.75 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 31.5) or (s == 31.75)):
                FN = FN + 1
            elif((s == 33.5 and str(all_targets[best_candidate_index]) == '吼') or (s == 33.75 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 33.5) or (s == 33.75)):
                FN = FN + 1
            elif((s == 34 and str(all_targets[best_candidate_index]) == '那') or (s == 34.25 and str(all_targets[best_candidate_index]) == '那')):
                TP = TP + 1
            elif((s == 34) or (s == 34.25)):
                FN = FN + 1
            elif((s == 36.25 and str(all_targets[best_candidate_index]) == '那') or (s == 36.5 and str(all_targets[best_candidate_index]) == '那')):
                TP = TP + 1
            elif((s == 36.25) or (s == 36.5)):
                FN = FN + 1
            elif((s == 40 and str(all_targets[best_candidate_index]) == '吼') or (s == 40.25 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 40) or (s == 40.25)):
                FN = FN + 1
            elif((s == 42 and str(all_targets[best_candidate_index]) == '吼') or (s == 42.25 and str(all_targets[best_candidate_index]) == '吼') or (s == 42.25 and str(all_targets[best_candidate_index]) == '那')):
                TP = TP + 1
            elif((s == 42) or (s == 42.25)):
                FN = FN + 1
            elif((s == 42.5 and str(all_targets[best_candidate_index]) == '那')):
                TP = TP + 1
            elif((s == 42.5)):
                FN = FN + 1
            elif((s == 46 and str(all_targets[best_candidate_index]) == '吼') or (s == 46.25 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 46) or (s == 46.25)):
                FN = FN + 1
            elif((s == 53 and str(all_targets[best_candidate_index]) == '吼') or (s == 53.25 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 53) or (s == 53.25)):
                FN = FN + 1
            elif((s == 55 and str(all_targets[best_candidate_index]) == '吼') or (s == 55.25 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 55) or (s == 55.25)):
                FN = FN + 1
            elif((s == 56.25 and str(all_targets[best_candidate_index]) == '吼') or (s == 56.5 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 56.25) or (s == 56.5)):
                FN = FN + 1
            elif((s == 59.25 and str(all_targets[best_candidate_index]) == '吼') or (s == 59.5 and str(all_targets[best_candidate_index]) == '吼')):
                TP = TP + 1
            elif((s == 59.25) or (s == 59.5)):
                FN = FN + 1
            elif(str(all_targets[best_candidate_index]) != '其他' and str(all_targets[best_candidate_index]) != '他' and str(all_targets[best_candidate_index]) != '你' and str(all_targets[best_candidate_index]) != '我' and str(all_targets[best_candidate_index]) != '的' and str(all_targets[best_candidate_index]) != '好' and str(all_targets[best_candidate_index]) != 'backgroundNoise'):
                FP = FP + 1
            else:
                TN = TN + 1
        else:
            if(s != 3.25 and s != 5 and s != 5.25 and s != 5.75 and s != 6 and s != 8.75 and s != 9 and s != 9.25 and s != 11.25 and s != 11.5 and s != 11.75 and s != 12 and s != 13 and s != 13.25 and s != 14 and s != 14.25 and s != 14.75 and s != 15 and s != 15.25 and s != 16.25 and s != 16.75 and s != 19.25 and s != 23.5 and s != 23.75 and s != 28 and s != 28.25 and s != 28.5 and s != 31.5 and s != 31.75 and s != 33.5 and s != 33.75 and s != 34 and s != 34.25 and s != 36.25 and s != 36.5 and s != 40 and s != 40.25 and s != 42 and s != 42.25 and s != 42.5 and s != 46 and s != 46.25 and s != 53 and s != 53.25 and s != 55 and s != 55.25 and s != 56.25 and s != 56.5 and s != 59.25 and s != 59.5):
                TN = TN + 1
            else:
                FN = FN + 1

#main
# Parameters
model_path = './h5_normalize/recording9_fbank.h5'
all_targets = ['backgroundNoise', 'ㄏㄧㄡ', 'ㄟ', '他', '你', '其他', '吼', '啦', '嗯', '好', '我', '的', '著', '那', '阿']

start = 0 #一開始的索引值
end = 4000 #一開始的索引值
s = 0 #秒
m = 0 #分
duration = 60 #讀音檔的總時間
sample_rate = 16000 #取樣率

#載入音檔
y, sr = librosa.load("./TestWAV/TestWAV2.wav",sr=sample_rate,duration=duration) 

# Sliding window
window = np.zeros(8000)#取樣音頻數據變數

# Load model
model = models.load_model(model_path)


while True:
    s = s + 0.25 #增加秒數
    if(s >= 60): #60秒 轉成 1分
        s = 0
        m = m + 1

    window[:4000] = window[4000:] #把音訊載入window
    window[4000:] = y[start:end] #把音訊載入window
    
    sound(window,s,m) #呼叫sound()

    if(end == (16000 * duration)): #如果移動到最後，break
        break
    
    start = start + 4000 #向後移動
    end = end + 4000 #向後移動    
    
print("TP = " + str(TP))
print("TN = " + str(TN))
print("FP = " + str(FP))
print("FN = " + str(FN))

# %%
#單詞測試
TN = 0
TP = 0
FP = 0
FN = 0


# This gets called every 0.5 seconds
def sound(window,s,m):
    global TN
    global TP
    global FP
    global FN
    S = np.abs(librosa.stft(window)) #將整個window音訊做stft，並轉成絕對值
    
    if np.sum(S) >= 500: #判斷S的總和是否>=500，如果>=500，代表有明顯的聲音
        window = window.astype(np.float)

        window = (window - window.mean()) / (window.max() - window.min())

        features = python_speech_features.base.logfbank(window,
                                                        samplerate=16000,
                                                        winlen=0.025,
                                                        winstep=0.01,
                                                        nfilt=26,
                                                        nfft=512,
                                                        lowfreq=0,
                                                        highfreq=None,
                                                        preemph=0.97)

        features = np.float32(features.reshape(1, features.shape[0], features.shape[1], 1))

        prediction = model.predict(features).reshape((15, ))
        prediction /= prediction.sum()
        best_candidate_index = prediction.argmax()

        best_candidate_probability = prediction[best_candidate_index]

        if(best_candidate_probability > 0.7): # treshold
            if(str(all_targets[best_candidate_index]) != "backgroundNoise"):
                data.append(str(all_targets[best_candidate_index]) + " " + str(m) + "分" + str(s) + "秒" + " 預測值:" + str(best_candidate_probability)) 
        

#main
# Parameters
model_path = './h5_normalize/recording9_fbank.h5'
all_targets = ['backgroundNoise', 'ㄏㄧㄡ', 'ㄟ', '他', '你', '其他', '吼', '啦', '嗯', '好', '我', '的', '著', '那', '阿']

data = []
start = 0 #一開始的索引值
end = 4000 #一開始的索引值
s = 0 #秒
m = 0 #分
duration = 10 #讀音檔的總時間
sample_rate = 16000 #取樣率

#載入音檔ㄏㄧㄡ ㄟ 吼 啦 嗯 著 那 阿
y, sr = librosa.load("./TestWAV/阿.wav",sr=sample_rate,duration=duration) 

# Sliding window
window = np.zeros(8000)#取樣音頻數據變數

# Load model
model = models.load_model(model_path)


while True:
    s = s + 0.25 #增加秒數
    if(s >= 60): #60秒 轉成 1分
        s = 0
        m = m + 1

    window[:4000] = window[4000:] #把音訊載入window
    window[4000:] = y[start:end] #把音訊載入window
    
    sound(window,s,m) #呼叫sound()

    if(end == (16000 * duration)): #如果移動到最後，break
        break
    
    start = start + 4000 #向後移動
    end = end + 4000 #向後移動    
    
    
for i in range(len(data)):
        print(data[i])
